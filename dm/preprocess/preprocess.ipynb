# %%
import pandas as pd
import numpy as np
import random

lists = ["back_end", "mobile", "front_end", "ai", "game", "test", "support", "data"]

data1 = pd.DataFrame()
for i in lists:
    data1 = pd.concat([data1, pd.read_csv("/Users/emisonlu/Desktop/Data-Mining/dm/spider/shanghai/" + i + ".csv")], axis=0)
data1 = data1.iloc[:,1:]
data1.insert(data1.shape[1], "city", "上海")

data2 = pd.DataFrame()
for i in lists:
    data2 = pd.concat([data2, pd.read_csv("/Users/emisonlu/Desktop/Data-Mining/dm/spider/beijing/" + i + ".csv")], axis=0)
data2 = data2.iloc[:,1:]
data2.insert(data2.shape[1], "city", "北京")

data3 = pd.DataFrame()
for i in lists:
    data3 = pd.concat([data3, pd.read_csv("/Users/emisonlu/Desktop/Data-Mining/dm/spider/shenzhen/" + i + ".csv")], axis=0)
data3= data3.iloc[:,1:]
data3.insert(data3.shape[1], "city", "深圳")

data4 = pd.DataFrame()
for i in lists:
    data4 = pd.concat([data4, pd.read_csv("/Users/emisonlu/Desktop/Data-Mining/dm/spider/guangzhou/" + i + ".csv")], axis=0)
data4 = data4.iloc[:,1:]
data4.insert(data4.shape[1], "city", "广州")

data5 = pd.DataFrame()
for i in lists:
    data5 = pd.concat([data5, pd.read_csv("/Users/emisonlu/Desktop/Data-Mining/dm/spider/hangzhou/" + i + ".csv")], axis=0)
data5 = data5.iloc[:,1:]
data5.insert(data5.shape[1], "city", "杭州")

data6 = pd.DataFrame()
for i in lists:
    data6 = pd.concat([data6, pd.read_csv("/Users/emisonlu/Desktop/Data-Mining/dm/spider/chengdu/" + i + ".csv")], axis=0)
data6 = data6.iloc[:,1:]
data6.insert(data6.shape[1], "city", "成都")

data7 = pd.DataFrame()
for i in lists:
    data7 = pd.concat([data7, pd.read_csv("/Users/emisonlu/Desktop/Data-Mining/dm/spider/chongqing/" + i + ".csv")], axis=0)
data7 = data7.iloc[:,1:]
data7.insert(data7.shape[1], "city", "重庆")


data = pd.concat([data1, data2, data3, data4, data5, data6, data7], axis=0)

# %%
data.drop_duplicates(subset=['job_name', 'company_name', 'work_area', 'salary'], keep='first')
# Out:
#    big_category small_category            job_name    company_name  \
# 0          后端开发      Java开发工程师         Java资深开发工程师  丰益（上海）信息技术有限公司
# 1          后端开发      Java开发工程师           Java开发工程师  上海第九城市信息技术有限公司
# 2          后端开发      Java开发工程师           Java开发工程师      上海砾阳软件有限公司
# 3          后端开发      Java开发工程师  Java高级开发工程师（大数据方向）    上海金指软件技术有限公司
# 4          后端开发      Java开发工程师           java软件工程师    上海久华信息科技有限公司
# ..          ...            ...                 ...             ...
# 48           数据        数据治理工程师              数据处理专员    重庆电政信息科技有限公司
# 49           数据        数据治理工程师             数据治理工程师  数字重庆信息技术服务有限公司
# 50           数据        数据治理工程师             数据治理工程师   重庆数宜信信用管理有限公司
# 51           数据        数据治理工程师            数据库实施工程师      重庆云华科技有限公司
# 52           数据        数据治理工程师             数据管理与运营    重庆联合飞创科技有限公司
#
#         salary work_area company_type work_year  education recruitment_scale  \
# 0     2.5-3万/月   上海-浦东新区      外资（非欧美）   10年以上经验        6.0               招1人
# 1   1.5-2.5万/月    上海-虹口区         上市公司      2年经验        6.0               招1人
# 2       1-2万/月   上海-浦东新区         民营公司      1年经验        6.0              招10人
# 3   1.5-2.5万/月   上海-浦东新区         民营公司    5-7年经验        6.0               招6人
# 4     0.6-1万/月    上海-宝山区         民营公司      1年经验        5.0              招若干人
# ..         ...       ...          ...       ...        ...               ...
# 48    2-4.5千/月    重庆-渝北区         民营公司      无需经验        NaN               招2人
# 49    1-1.5万/月    重庆-渝北区           国企    3-4年经验        7.0               招1人
# 50      1-2万/月    重庆-巴南区         民营公司    3-4年经验        6.0               招1人
# 51    4.5-6千/月   重庆-九龙坡区         民营公司      2年经验        6.0               招5人
# 52    1-1.5万/月    重庆-渝北区         民营公司    3-4年经验        6.0              招若干人
#
#                                               welfare company_size city
# 0           五险一金 补充医疗保险 员工旅游 餐饮补贴 通讯补贴 年终奖金 绩效奖金 定期体检    500-1000人   上海
# 1                            五险一金 带薪年假 交通补贴 餐饮补贴 做五休二      50-150人   上海
# 2        做五休二 周末双休 带薪年假 五险一金 绩效奖金 节日福利 专业培训 餐饮补贴 加班补贴     150-500人   上海
# 3   五险一金 餐饮补贴 定期体检 专业培训 免费班车 员工旅游 交通补贴 年终奖金 股票期权 绩效奖金      50-150人   上海
# 4        做五休二 周末双休 弹性工作 带薪年假 五险一金 绩效奖金 节日福利 专业培训 年终奖金        少于50人   上海
# ..                                                ...          ...  ...
# 48  五险一金 绩效奖金 周末双休 员工宿舍 弹性工作 全勤奖 节假日福利 交通补贴 餐饮补贴 半...      50-150人   重庆
# 49                               五险一金 定期体检 绩效奖金 免费工作餐     150-500人   重庆
# 50                                          五险一金 绩效奖金      50-150人   重庆
# 51       五险一金 员工旅游 交通补贴 餐饮补贴 专业培训 出国机会 年终奖金 弹性工作 定期体检      50-150人   重庆
# 52                           年终奖金 餐饮补贴 周末双休 五险一金 绩效奖金      50-150人   重庆
#
# [66966 rows x 13 columns]

# %%
def process_internship(d:str):
    if "实习" in d:
        return "1"
    else:
        return d

data['job_name']=data.apply(lambda x:process_internship(x['job_name']), axis=1)
data.index = range(len(data))
data = data.drop(data[data['job_name'] == "1"].index)

# %%
def process_salary(d:str):
    try:
        if "万/月" in d:
            d = d[:-3]
            d1 = float(d.split('-')[0])
            d2 = float(d.split('-')[1])
            return round((d1 + d2) / 2.0, 2)
        elif "万/年" in d:
            d = d[:-3]
            d1 = float(d.split('-')[0])
            d2 = float(d.split('-')[1])
            return round((d1 + d2) / 24.0, 2)
        elif "千/月" in d:
            d = d[:-3]
            d1 = float(d.split('-')[0])
            d2 = float(d.split('-')[1])
            return round((d1 + d2) / 20.0, 2)
        else:
            return 0
    except Exception:
        return 0

data['salary'] = data.apply(lambda x:process_salary(x['salary']), axis=1)
data = data.drop(data[(data['salary'] < 0.2) | (data['salary'] > 10)].index)

# %%
def process_area(d:str):
    if "-" in d:
        return d[3:]
    else:
        return ""

data['work_area']=data.apply(lambda x:process_area(x['work_area']), axis=1)

# %%
def process_work_year(d:str):
    if "3-4" in d:
        return random.randint(3, 4)
    elif "2年" in d:
        return 2
    elif "1年" in d:
        return 1
    elif "5-7" in d:
        return random.randint(5, 7)
    elif "8-9" in d:
        return random.randint(8, 9)
    elif "10" in d:
        return 10
    elif "招" in d:
        return random.randint(0, 10)
    else:
        return 0

data['work_year']=data.apply(lambda x:process_work_year(x['work_year']), axis=1)

# %%
def process_education(d:int):
    if d > 0:
        return int(d)
    else:
        return random.randint(0, 8)

data['education']=data.apply(lambda x:process_education(x['education']), axis=1)

# %%
def process_recruitment_scale(d:str):
    if d == "招若干人":
        return random.randint(1, 10)
    elif "招" in d:
        return int(d[1:-1])
    else:
        return random.randint(1, 10)

data['recruitment_scale']=data.apply(lambda x:process_recruitment_scale(x['recruitment_scale']), axis=1)

# %%
dist = {}
for index, row in data.iterrows():
    lists = str(row['welfare']).split(" ")
    for i in lists:
        if i in dist:
            dist[i] = dist[i] + 1
        else:
            dist[i] = 1
dist = sorted(dist.items(), key=lambda x: x[1], reverse=True)
len(dist)
# Out:
# 1992

# %%
def process_welfare(d:str):
    res = "s"
    lists = ['五险一金', '年终奖金', '绩效奖金', '定期体检', '员工旅游', '餐饮补贴', '专业培训', '弹性工作', '交通补贴', '通讯补贴', '周末双休', '补充医疗保险', '带薪年假', '节日福利', '股票期权']
    try:
        for i in lists:
            if i in d:
                res = res + "1"
            else:
                res = res + "0"
        return res
    except Exception:
        return ""
        

data['welfare']=data.apply(lambda x:process_welfare(x['welfare']), axis=1)
data.to_csv("data.csv")
data
# Out:
#       big_category small_category            job_name    company_name  salary  \
# 0             后端开发      Java开发工程师         Java资深开发工程师  丰益（上海）信息技术有限公司    2.75
# 1             后端开发      Java开发工程师           Java开发工程师  上海第九城市信息技术有限公司    2.00
# 2             后端开发      Java开发工程师           Java开发工程师      上海砾阳软件有限公司    1.50
# 3             后端开发      Java开发工程师  Java高级开发工程师（大数据方向）    上海金指软件技术有限公司    2.00
# 4             后端开发      Java开发工程师           java软件工程师    上海久华信息科技有限公司    0.80
# ...            ...            ...                 ...             ...     ...
# 77344           数据        数据治理工程师             数据治理工程师  数字重庆信息技术服务有限公司    1.25
# 77345           数据        数据治理工程师             数据治理工程师   重庆数宜信信用管理有限公司    1.50
# 77346           数据        数据治理工程师            数据库实施工程师      重庆云华科技有限公司    0.53
# 77347           数据        数据治理工程师             数据管理与运营    重庆联合飞创科技有限公司    1.25
# 77348           数据        数据治理工程师               数据管理员   重庆数宜信信用管理有限公司    0.95
#
#       work_area company_type  work_year  education  recruitment_scale  \
# 0          浦东新区      外资（非欧美）         10          6                  1
# 1           虹口区         上市公司          2          6                  1
# 2          浦东新区         民营公司          1          6                 10
# 3          浦东新区         民营公司          7          6                  6
# 4           宝山区         民营公司          1          5                  1
# ...         ...          ...        ...        ...                ...
# 77344       渝北区           国企          3          7                  1
# 77345       巴南区         民营公司          3          6                  1
# 77346      九龙坡区         民营公司          2          6                  5
# 77347       渝北区         民营公司          4          6                  4
# 77348       渝北区         民营公司          4          6                  1
#
#                 welfare company_size city
# 0      s111111000101000    500-1000人   上海
# 1      s100001001000100      50-150人   上海
# 2      s101001100010110     150-500人   上海
# 3      s111111101000001      50-150人   上海
# 4      s111000110010110        少于50人   上海
# ...                 ...          ...  ...
# 77344  s101100000000000     150-500人   重庆
# 77345  s101000000000000      50-150人   重庆
# 77346  s110111111000000      50-150人   重庆
# 77347  s111001000010000      50-150人   重庆
# 77348  s101000000000000      50-150人   重庆
#
# [73969 rows x 13 columns]
